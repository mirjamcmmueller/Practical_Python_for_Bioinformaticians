# %% [markdown]
# # 1. Introduction and Setup
# *28.05.2026, Mirjam Müller*
#
# This is by no means a complete guide. That would be like asking me to write a document on the entirety of the english language. don't expect it to be that. However, I hope it helps somewhat to get an idea of the basics. Or at least those basics needed for a Bioinformatician first tackling python to get started and not feel like dying.
#
# Python is hard in the beginning. It can be overwhelming and emotional, and quite the beast to tame. I hope this helps with the overwhelm though. See it as like a cheatsheet.
#
# I have structured it into sections:
#
# 1. Lists, dictionaries and all that other stuff
# 2. H
